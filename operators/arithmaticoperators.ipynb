# %% [markdown]
# ARITHMATIC OPERATORS

# %%
a = 10
b = 20
print(a+b) #add
print(a-b) #subtract
print(a*b) #multiply
print(a/b) #divide
print(a//b) #floor division
print(a%b) #modulus - remainder
print(a**b) #exponational
# Out:
# 30
# -10
# 200
# 0.5
# 0
# 10
# 100000000000000000000

# %% [markdown]
# Identity operator :-- it is use to compare the memory location of var, obj etc.....
#
# is - true
# is not - ture

# %%
a = ["parul","shreya"]
b = a
c = (34,32,45)

print(a is b)
# Out:
# True

# %%
print(a is c)
# Out:
# False

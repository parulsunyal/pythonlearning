# %% [markdown]
# Membership operator :--  this is use to check the value is exist in the object or not
#
# in
# not it

# %%
a = [23,45,56]
print(45 in a)
# Out:
# True

# %%
print(67 not in a)
# Out:
# True

# %%
print(23 not in a)
# Out:
# False

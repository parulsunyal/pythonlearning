# %% [markdown]
# LOGICAL OPERATORS :--
#     multiple condition combine  - boolean return
#     1. AND
#     2. OR
#     3. NOT

# %%
x = 10
y = 30

print(x>y AND y<x)
print(x == 10 OR y != 30)
print(NOT x < 20)
# Out:
#   Cell In[2], line 4
#     print(x>y AND y<x)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

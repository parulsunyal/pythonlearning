# %% [markdown]
# COMPARSION  OPERATOR :-- ONLY RETURN BOOLEAN VALUE

# %%
x = 10
y = 23

print(x == y) #equal to
print(x != y) # not equal to
print(x > y) #greater then
print(x < y) # less then
print(x >= y) #greatern then equal to 
print(x <= y)  # less then equal to
# Out:
# False
# True
# False
# True
# False
# True

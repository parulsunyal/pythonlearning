# %%
age = int(input("enter the age of perosn :-- "))
if age <= 18:
    print("you are not eligible.")
elif age >= 18 and age <= 60:
    print("you can vote.")
else:
    print("you are over age.")
# Out:
# enter the age of perosn :--  65
# you are over age.
